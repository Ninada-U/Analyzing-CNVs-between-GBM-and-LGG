# %%
import requests
import json
import pprint

fields = [
#     'files.data_category',
#     'files.data_format',
#     'files.file_id',
    'annotations.entity_id'
    ]

fields = ",".join(fields)

endpt = "https://api.gdc.cancer.gov/file"

filters = {
    "op": "and",
    "content":[
        {
            'op': 'in',
            'content': {
                'field': 'project.program.name',  # program
                'value': ['TCGA']
            }
        },
        {
            'op': 'in',
            'content': {
                'field': 'project.name',  # project
                # either 'Glioblastoma Multiforme' or 'Brain Lower Grade Glioma'
                'value': ['Brain Lower Grade Glioma']
            }
        },
        {
            "op": "in",
            "content":{
                "field": "cases.project.primary_site",  # primary site
                "value": ["Brain"]
            }
        },
        {
            "op": "in",
            "content":{
                "field": "demographic.race",  # race
                "value": ["White"]
            }
        }
    ]
}

params = {
    "filters": filters,
    "fields": fields,
    'sort': 'submitter_id:asc',
    'size': 1000  # should be >= number of hits outputted
    }
js = requests.post(endpt, headers = {"Content-Type": "application/json"}, json = params).json()
print(js)
print('warnings: ', js['warnings'])
print('number of hits: ', js['data']['pagination']['total'])
print(json.dumps(js, indent=2))
case_files = {}
cases = []
for case in js['data']['hits']:
    pprint.pprint(case)
    vcfs = []
    cases.append(case['id'])
#     if any(d['data_format'] == 'VCF'):
#         for d in case['files']:
#             if d['data_format'] == 'VCF':
#                 vcfs.append(d['file_id'])
#         case_files[case['id']] = {'vcfs': vcfs}
#     if any((d['data_format'] == 'VCF' and \
#             d['data_category'] == 'Simple Nucleotide Variation') for d in case['files']):
#         for d in case['files']:
#             if d['data_format'] == 'VCF':
#                 vcfs.append(d['file_id'])
#         case_files[case['id']] = {'vcfs': vcfs}
# Out:
# {'message': 'The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-1f60a5879f03> in <module>
#      57 js = requests.post(endpt, headers = {"Content-Type": "application/json"}, json = params).json()
#      58 print(js)
# ---> 59 print('warnings: ', js['warnings'])
#      60 print('number of hits: ', js['data']['pagination']['total'])
#      61 print(json.dumps(js, indent=2))
#
# KeyError: 'warnings'

# %%
cases
# Out:
# ['334f715e-08dc-4a29-b8e4-b010b829c478',
#  'fc222f23-b3b2-4ac0-bc61-e8e8fa5cc160',
#  '952dfd5d-e65a-4307-b6a9-2ed2b0d2d9ce',
#  '64cd17eb-c778-45e9-b994-02b68182e51b',
#  'c6cf2b8e-40ed-4c9f-8419-d868bd5afe11',
#  'e8d3d888-e5fc-4469-ad0b-2c1df6e04790',
#  '97bf8065-3e7d-4702-a426-24908f4d66a4',
#  'b6c2c9bd-625b-4a98-830c-49c344f6cb5f',
#  'bdfade49-9059-4665-beea-c55117ba6564',
#  '9ee6e821-3af2-42d7-9d14-f0ca455f338c',
#  '3f70c3e3-0131-466f-92aa-0a63ab3d4258',
#  'c16d9f69-26f9-4ec7-b2d5-ff9f7dacfe0f',
#  '8cba230b-46db-4d35-8123-3879eba32402',
#  'ae081e4a-efa9-4b52-b15e-29085c0612d3',
#  'a5d3f3fb-6541-419d-b47e-720d438f1bff',
#  'dc5bdd21-b23f-400e-bbe2-4c98a517fc9e',
#  '60b30a95-3e4c-413a-9de6-16a5bca163c4',
#  'b95afb1a-a1df-4d85-ad34-191928e28a77',
#  'e326c1dd-2ef8-431b-a657-440aa3f35ff3',
#  'eb42625e-fbbb-4bee-bbe9-315b3ca2138a',
#  'ddfd76dc-15d6-4efc-85ea-31674161ebf3',
#  '1cc53ade-73c0-492b-a7dc-328269fd0e66',
#  'fcd9e1c4-bddb-4856-844c-03df48fba499',
#  '1937318f-a1bb-4f48-b8ec-4aadd406e52a',
#  '42cc9620-98fb-4164-a3b2-28d084ca5a03',
#  '6355cade-7b3a-43a8-9f1f-8e7bc45755a8',
#  '152eaa99-05f5-4d30-bfb1-494a9a900e49',
#  'e695b780-17f4-4e71-9120-7c6bcafaa3a7',
#  '4ef429be-c345-4258-9b42-b56e215e1a2c',
#  '178ab87c-0582-4b02-bf6b-3a4c59a5ee1b',
#  '97cb8701-7d63-4142-b404-006fbb3ecb0b',
#  '152f028e-ee29-40e0-8e75-5cafffacbd45',
#  '8daa29c0-f652-4130-a004-5183bbe30c63',
#  'c0d47e0f-4918-4e06-9db6-201671b1259c',
#  '9239a22e-80b1-49a2-b0d5-cbab7e415254',
#  'c13a429c-99ea-478c-ae95-fa499b9ea9fa',
#  '70939245-41e0-4845-a473-5fef719b9828',
#  '14375753-a69f-41e0-b910-2bb8e84cc43a',
#  '467a7e6a-8cba-4ef1-8afd-6c8eaccbc3df',
#  'cd69d509-a652-4257-a8d3-767296bbb4ec',
#  '215e117c-4d76-463c-8f8a-fd6a28d23929',
#  '8e2dcc00-9f7e-4dee-b24d-43c8b30294c5',
#  '427c40f6-d1bd-49f2-b303-a975793b937e',
#  '01c4ca12-ac08-41dd-9e4f-bfb0971688a2',
#  '834e560a-a506-456d-baf2-a206ca058153',
#  'cb598780-9e42-4167-b487-eec90ad4f36f',
#  'd61b5d20-4d6d-4fdc-afe8-4b100b686eda',
#  'a776cfd0-db9f-450a-943c-5a9a80a75fb7',
#  'ec82a00f-3909-4781-8ae2-e54cbc1ac7ac',
#  'f18dab99-26b0-4727-89a9-7f16bd382356',
#  '1b43ff0c-cf13-4620-b5c7-7abd9129612f',
#  'e00a9855-c15e-46ef-988f-25ca64ec4717',
#  '145f87a3-5e86-4a87-8e49-b166a2271d02',
#  '3f6ffb08-32a9-4555-bfd1-243b7f526105',
#  '81622da8-9f36-4ea3-b223-d831d8c10f87',
#  'a144e4e4-2877-4340-a2bf-524adbde8bc8',
#  '84ae73e4-3b39-4444-9bfb-3fc6057eab32',
#  '5a769292-c3ce-4e18-b821-2bfe0e24978c',
#  'd61710c1-8ac3-44e3-b567-66288a6ab731',
#  'c35f36b1-ba3d-4eea-bf5a-c95480202176',
#  'ca427acb-034e-42e2-961a-b9d5dc30b741',
#  'b8df1577-2a75-4eb7-ab27-f2dd76160730',
#  'b9a3b647-61b3-4d98-90ca-e307ab50984a',
#  '6fab9c30-354b-4f99-9b60-6823c12b9b0a',
#  'c81d4681-c02f-4b33-abe0-b6ad7d61194d',
#  'f97a9afe-e54a-4ef0-b458-0c77f938552e',
#  '11dffe71-b516-41e8-9987-e0ff5d2356d1',
#  'e09f93e1-1649-48fa-9e2e-d13ac6d50b97',
#  '68f550ca-3a33-45e4-b1c9-14f99e543263',
#  '648252da-dd86-48d1-ae75-4257e3142b0b',
#  '2cfc07f3-a31c-41a2-a9e3-b708d2421a78',
#  '8d07b1e8-5d1d-4a43-b616-d29dd58ce5fe',
#  'ad202887-88b3-4e0f-a4c3-7e135d4cb258',
#  'e4d9b696-3311-44e7-9191-fde56c080a00',
#  '5f10cd91-1e03-4016-b35a-8629a1a8fcc9',
#  '2d860614-b772-46e2-b1cd-43bb3ead7255',
#  'b342e980-8383-4f1b-bf57-4098c37a536c',
#  'c40ab957-fe46-43b1-992d-b4e2040a3f57',
#  '1f54d21e-752f-496d-8453-4b9b8738cbce',
#  '0f0d9a7f-dd85-48aa-b5b2-deff5bb6bdeb',
#  'b6f13250-31b3-46ad-b514-5a684f1094a9',
#  '1159c88c-39d0-4c03-9c66-36af5340a67a',
#  '6a0bcf0c-fa4c-4119-99d2-f722b781d20f',
#  'fb3884df-3680-4c5b-8092-981007aeba03',
#  'dcd45077-f068-490b-bdcc-4d4a62285116',
#  '0df37550-9421-4571-9844-51b457d7cb2b',
#  '106709ec-72df-44f0-8c71-87b7c755f8f0',
#  '5469c0e8-0c58-4870-b897-8fa0704599a7',
#  '029b33b1-7ea9-4b77-a615-7eb0e3ebd5e7',
#  'e30f1994-3622-43d0-bec2-6d7e2d9881d2',
#  '7662940a-22de-44d8-b59a-2f2b090ea6d5',
#  'dce168b1-d2a9-4409-8437-ab382f6d7d31',
#  'ad80a042-c4b4-445c-9678-1c2614422684',
#  'febe2ce5-737b-43b8-bc70-4194fe3ed5fb',
#  'c031f2a5-a563-4d5b-bd62-49d4fa5eca78',
#  'a85aebda-b182-41ba-815a-3ff055e22829',
#  '738f5c96-ee44-4fd7-bb8c-e2b86f8053c8',
#  'da13446a-c4dc-4d02-80c8-410273925ac4',
#  'ea31c705-4cf8-48f5-8d13-e43563213c91',
#  'ae4f0714-3b74-46c0-9c1b-f028c7cf2e62',
#  'c6ceb220-282e-4eef-8d36-4ce0a625cf7e',
#  '5b199e7e-cc23-4065-88ad-fdfe3d0683d6',
#  '1f5b6b07-45f5-4da4-932a-df9665f6c538',
#  'fa878a23-cd20-44ef-b438-33033b5fb1fe',
#  '7e17e6fd-ed83-471f-91e3-5934885c8e87',
#  '5b9d7565-a933-449d-8ffa-ec5f82db2e77',
#  'f4a1fc14-0d32-4e77-a8a3-fd8fea82188a',
#  'e6c55ba6-4c8a-4ea4-8dde-74d01915db02',
#  'b9e2f4d1-866c-4c62-a9c8-8de7eb364a6e',
#  'fee2114e-f723-4374-91f8-f1dcc6b3eaee',
#  '48314732-5d1c-43e6-9878-5b58dfaeb06a',
#  '482d4078-7576-48cf-bf7c-29014935fd47',
#  'dbfaccb0-e8c0-48e8-9aef-570267574822',
#  '72aa812d-5daa-4bd7-9028-ec541b1f25bd',
#  '41456932-436e-4cdb-bfe8-97d089656786',
#  '27d0d3cb-16c0-4ba8-9662-95917f665004',
#  '38f4b9f3-6709-40ff-9a81-5fa2111b1ce6',
#  '9351b1ae-89e6-4091-934f-d50da06cd01d',
#  'e669a4b7-a494-490a-b78c-e664c59d0697',
#  '81076cfb-f9d7-4add-b696-6eab0bad7945',
#  '80db28ec-ab3d-42a7-af88-b60fe8acb5b5',
#  '9d93834a-3bf0-41fd-8c74-5ac49a6e78cd',
#  '5de6fd84-ed02-4c27-9947-db57f05faf6d',
#  'd766c3af-f0b3-4791-a754-d6546d370f8f',
#  'bae316e3-1fa4-4fa7-8ad6-a458857a85d4',
#  'f2d3fea5-0d20-42d3-b918-adad715be4ee',
#  '81fb338f-1023-49aa-ac0f-ba763a6cd68c',
#  'c7b2833a-9fe8-49f6-b888-2d27b0516f5c',
#  'ad1c5951-ca93-4102-889b-e28e2bcfea76',
#  '975c76cd-f88a-4d88-93a4-fbf2cb9e2e3b',
#  '0906ddde-02fa-417d-927b-1c400b189cac',
#  '9b288f0e-5155-4736-bc22-e0e801d8b738',
#  'dd7b23a7-b41b-4670-9fc8-78895fb00cff',
#  'f625e522-226b-450f-af94-dd2f5adb605e',
#  '6d020185-bdde-4c43-9e38-71c6ed0c13d1',
#  '274496d6-0a9b-45ca-876f-b91f7277963c',
#  '618f2aa7-d1b6-430d-a157-d3d956edefbe',
#  '7e41baba-7ef6-4030-b595-d95cd96336b5',
#  'e117fcf4-2c01-4b4d-8faf-5de7d0e839f1',
#  '5a2d3bfa-4bdd-417d-9796-e3699760114c',
#  '04d56bed-98fb-45eb-8c90-95e69264dfe2',
#  '8655fa51-d784-4f8d-9bc8-f1da7303d22f',
#  '001ad307-4ad3-4f1d-b2fc-efc032871c7e',
#  'e89f7631-fdac-4be9-9997-70e400efdc04',
#  'd43581a5-3d49-4263-862b-ca99d15ec03d',
#  'a4e2e507-7ddf-43df-b959-fe451971af1e',
#  'effb5839-24a2-4b8c-8b6d-08cb66503d16',
#  'cf2a1b98-5693-4c04-9167-f85e69a88a4a',
#  '77396ae6-3838-47bf-aaae-f9a0f401ec7f',
#  'fdff46a7-f92a-45cf-8756-6c73a406c923',
#  '1a20f675-d9bb-48b0-a49f-d52270bd8973',
#  'a3be4e6f-c845-4d64-8111-d63fdf8cc8f1',
#  '559a8f6f-dd60-43b7-ae09-16cc4206064c',
#  '723cad09-aa2d-4492-b19d-661b310e1c58',
#  '55a67639-ed05-4143-af96-a377bc5489ee',
#  '42251e02-b687-4bf1-a1b6-e3dd978542e4',
#  '6957d45e-7ccb-457d-800d-c2a2037f4f01',
#  'c3c41fd2-f0d7-4f46-9e18-cce4626538c2',
#  'a85fdb41-24c1-420d-8905-ec297f018bd9',
#  'debe24c5-e4df-4e80-82f6-8f40395aa9e6',
#  '49967a57-7c12-46bb-8d71-cebbb17c9935',
#  'bc3b4816-df1d-44ed-a8c6-f32c8e011a1f',
#  'e3ed0c19-6acc-4be1-aae2-73fe73cc9f24',
#  '36cf458b-3c8e-48e7-92ab-aea1c698e417',
#  '6105c037-90f1-42d9-ac38-6e2252999a64',
#  '8996dc64-8c5e-4e07-8ed8-2eb11c03626b',
#  '62088274-a45b-4616-b086-b0ddd64895f0',
#  'a96bca45-ecc7-44f6-acb6-48b0cec3de4d',
#  '345d975c-e666-4614-81eb-5ccbb5bd2cf7',
#  '65836b59-b469-4b89-adf5-e65735e494f5',
#  '5119aceb-ad95-4904-b6c0-a0a4b42c17d0',
#  'dc7ec60b-5ea5-48a4-8908-55caf9214272',
#  '739cc9f1-71be-4f81-a5d1-eda673903e45',
#  '172701cf-709b-4e8f-b2fa-e2690a9e272d',
#  '145c3685-f6de-4669-8ec4-6c3431a90532',
#  '1f2f3bf6-acdd-4a72-8c33-230de40910eb',
#  '36615695-921c-4c8a-93d6-6c788079beae',
#  'fff304a2-113f-499d-a88c-9d3660c348d9',
#  '41e4dc71-7767-44c2-9d38-110dcd37b451',
#  '688fc346-a14d-4859-8727-057cd0a0b880',
#  '048056cd-39dd-4134-a58b-70bebb3dd2ff',
#  'c45e02e5-7e3c-4f36-8b8d-f54617e8a436',
#  '432fe4a9-2cdc-4323-aff0-59e2fdeda194',
#  'dcbbaca6-a24b-4bed-95de-314cff71e436',
#  'b297c4dc-ec58-4392-908a-586e81d57ef0',
#  'a343fbe3-147a-4656-9e90-5408298ca12c',
#  'a5e10e2e-5157-487b-88dc-6c70ad5e244a',
#  '41fbb9f1-4a13-48ab-8649-0608c89cdd9f',
#  '621424ec-67bc-4c42-b0ad-64c5654b5ad9',
#  '8ed09a8a-3284-4a1b-b369-e25d2fab0f61',
#  'b10a9314-fd40-459e-97ea-affc636dceea',
#  '38eca720-ad68-43a7-8a1c-f79f838d5d03',
#  'e6b7420f-4315-46a8-aed5-5c47cce5ded3',
#  'dd85dbb2-31c3-4bc2-9dff-3bd27c79a9ad',
#  '3e4851ca-4d69-4035-a2dd-8ed6e70f1ffb',
#  '6d2c49c3-0721-4bd2-b39f-7872f2de996d',
#  'a1192df3-7667-4d1e-a1a0-79f6cc827dcf',
#  '0bde34dd-dae9-4533-98ef-f5a61a11e7c4',
#  '0b283f95-dbd4-4c36-9201-2198a90ee0d6',
#  'd62d871b-4612-4bf4-b53c-9dd431e507a0',
#  'f79420ca-b0ae-417c-95f7-d28c35760202',
#  'a418fe65-dfdd-4c84-b27c-b4567b50f457',
#  'a2202233-4a83-4163-9532-b6edb9941453',
#  '081b6532-0ed4-445a-becb-cb2290f4854d',
#  '14e6c57d-d78e-4660-a21f-4f90a4503080',
#  'cc451e2a-fa85-42d7-b7af-9fc0166945fa',
#  'f6a81d81-7df4-4273-8a86-e0cd3b8b1df5',
#  'a80b0fab-6189-497f-997f-77234b69179c',
#  '94b95c07-5f70-4a1b-b40f-dc13f6a160d5',
#  '01a13aba-74a4-4895-a5ad-e5119925c202',
#  '6a8241a8-d9ee-414b-89fd-4c3b9f181cc7',
#  '33bedfb7-33fb-479d-b997-50c3284c0ac9',
#  '194e8231-e8d4-477f-8c62-e11f2484ecce',
#  '032096a6-1923-44b9-a1cb-181bed041c8e',
#  '765588aa-075f-477f-9c18-099d018d3a1b',
#  '427f4d23-2b76-4a2a-a498-0c3473f57169',
#  '94a2ff09-f7ac-4aea-a2b2-0dc1b82ae635',
#  '79627774-078d-4056-84b3-f1f370f643e0',
#  '78a212bc-a740-46bf-a10d-0b9809a5bb3f',
#  '8e44fb97-c649-4056-80ac-257cef61d226',
#  'b7395082-415b-4ab3-bf1e-59d0f4e4b488',
#  '58650d08-7685-41de-9ae0-21665f8f449f',
#  'a6975eb0-cfa6-4b7a-bbe4-72bbdd3d3b6f',
#  '7883e417-a793-4614-9528-6c2e9e44379f',
#  'c4f522c9-bff5-4899-8d27-c105dab795a9',
#  'cc8614c4-d535-4ad9-82f0-f4dc7ad11d0f',
#  'd13ac936-87a9-4164-bdab-02ccf3908cfe',
#  'f5416dc4-d161-4776-9827-e4ceaf42d19f',
#  '84d80bcf-da24-4b93-bfe3-3d2d53b8b07d',
#  '288f6c7e-d96f-4be1-8312-77c67f75c467',
#  '033c1f48-9225-4159-b23b-7042272877da',
#  'ee6bf12f-8a73-49e2-b566-368b2b42165b',
#  '8643437f-cd1b-47c8-86bd-87b6c2f80747',
#  '3b68b6ff-7efb-4d53-8bd8-c76cd68ab7c0',
#  '63f4aa26-dec0-4309-8b75-6446a7241527',
#  'edbf86e5-3f55-4ddf-a97f-3e9dc607e53d',
#  '71ec4c84-4aef-4c1f-ab07-dc264c5c0602',
#  'b3720405-ce3f-49c7-a5d9-bbffd06f6aef',
#  '9b161c41-4f76-4ed1-b60f-2b093bc70edb',
#  '61ff31a4-4fdc-476c-b456-2a2fed4bae6b',
#  '8839f236-bc04-416f-84d4-50f67fb338dc',
#  'fcf14e9d-4671-453d-b8e0-5008e916f56d',
#  '21bbe030-8dbb-47eb-a670-13eb57c12159',
#  'cd50aea8-a5db-48d3-ad28-cbe9f9e75ae3',
#  'f9052682-b689-4696-9ab9-3f55976b43ee',
#  'f5268956-789d-4b22-8f19-a3ac9353d33d',
#  '619e18c1-09b9-468c-816d-6789c0bef0a8',
#  '7989b7fb-b9d9-4d3f-9352-cd0c1f28d828',
#  'df78e63d-4387-4177-b24f-f0e2c6c7ac32',
#  '2f8c789e-bbd8-4753-a48b-6894c21162f8',
#  '3431a71c-fabf-440c-b11c-8acfee04724f',
#  'c05f9e21-b8fa-4537-9ae7-39d6fc9d7933',
#  'e2b1d161-d8cc-4eba-87ac-9449c6cd2977',
#  '607b1f22-b744-43c5-91f7-fc69142ba30e',
#  '44553e34-5111-40a8-b76a-254751be3f87',
#  'b19dcbc2-b0d4-4759-9213-1a5b99df7e76',
#  '5a3edeb6-133e-4116-9f80-2485bd70754d',
#  'f878bf8d-70eb-4b74-bf74-bdf63cb9bfae',
#  '135a149a-d153-465e-aa58-06d47bb18e00',
#  'a66a3847-7570-4486-8845-86b6125104a2',
#  'b3f0dece-94e8-4eaf-91bc-4b3f4dae12d2',
#  '66c52a31-6503-40b5-a55e-fa476eaf0567',
#  '0073a136-d5f4-4fd6-88f9-711768f2abc6',
#  '484dd45b-a16c-4650-bac9-832fbe4d96eb',
#  '10887e42-444d-49fc-aee5-dd0e9fc4ea54',
#  '4fb16aee-df08-441a-846b-558e0efe8342',
#  '732df38e-d32c-4d63-ac97-ad655e2e5732',
#  '42156c6a-416e-4832-9c95-cee6084b0910',
#  'c8700ca3-8c0b-4b2a-9e87-79d244a0f892',
#  'de6f01bf-2de9-4d07-a956-e6a4c0acb371',
#  '09552b53-4393-4811-a671-a9ef6eff4790',
#  'cb041720-0efa-4eb6-a9a5-b6e138bb1a99',
#  'f62be2b8-88c4-4a7e-8c80-8176fb5f6c56',
#  '0d5a4c63-c3fb-4295-a433-d90cdbfc4ed6',
#  '2272dff7-a509-496f-b500-467c1bce2f79']

# %%
import requests
import json
import pprint

fields = [
    'files.data_category',
    'files.data_format',
    'files.file_id',
    'exposures.cigarettes_per_day'
    ]

fields = ",".join(fields)

endpt = "https://api.gdc.cancer.gov/cases"

filters = {
    "op": "and",
    "content":[
        {
            'op': 'in',
            'content': {
                'field': 'project.program.name',  # program
                'value': ['TCGA']
            }
        },
#         {
#             'op': 'in',
#             'content': {
#                 'field': 'project.name',  # project
#                 # either 'Glioblastoma Multiforme' or 'Brain Lower Grade Glioma'
#                 'value': ['Glioblastoma Multiforme']
#             }
#         },
        {
            "op": "in",
            "content":{
                "field": "cases.project.primary_site",  # primary site
                "value": ["bronchus and lung"]
            }
        },
        {
            "op": "in",
            "content":{
                "field": "demographic.race",  # race
                "value": ["White"]
            }
        }
    ]
}

params = {
    "filters": filters,
    "fields": fields,
    'sort': 'submitter_id:asc',
    'size': 5  # should be >= number of hits outputted
    }
js = requests.post(endpt, headers = {"Content-Type": "application/json"}, json = params).json()
print('warnings: ', js['warnings'])
print('number of hits: ', js['data']['pagination']['total'])
# print(json.dumps(js, indent=2))
case_files = {}
for case in js['data']['hits']:
    pprint.pprint(case)
    vcfs = []
    if any((d['data_format'] == 'VCF' and \
            d['data_category'] == 'Simple Nucleotide Variation') for d in case['files']):
        for d in case['files']:
            if d['data_format'] == 'VCF':
                vcfs.append(d['file_id'])
        case_files[case['id']] = {'vcfs': vcfs}

# %% [markdown]
# Post Request to Download Multiple Files

# %%
import requests
import json
import re

data_endpt = "https://api.gdc.cancer.gov/data"

for case in list(case_files.keys())[:1]:
    ids = case_files[case]['vcfs']
    print(ids)


params = {"ids": ids}

response = requests.post(data_endpt,
                        data = json.dumps(params),
                        headers={
                            "Content-Type": "application/json"
                            })
# Out:
# ['ca9b0df8-a440-4c4f-9bad-4c877da13955', '82c0449d-53cf-4e78-8a13-ffb501ead24f', '5d6a6b23-6b16-4938-ac3f-022fa5367a6c', '18d86dda-71e8-495a-a6f5-4a43e66c2e6f', '5909647c-05c4-47da-9bc9-30b77f21047a', 'b7a0f479-7c15-436f-9c2f-088d1d11ab32', 'f81d138e-62ef-4491-b4d0-65c2e07957b9', 'ca262127-69db-4836-b4d3-a5726e80ce77']

# %%
response  # need access token
# Out:
# <Response [403]>

# %%
response_head_cd = response.headers["Content-Disposition"]

file_name = re.findall("filename=(.+)", response_head_cd)[0]

with open(file_name, "wb") as output_file:
    output_file.write(response.content)

# %%
file_name
# Out:
# 'gdc_download_20200411_204637.810914.tar.gz'
